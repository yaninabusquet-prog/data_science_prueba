# %% [markdown]
# <a href="https://colab.research.google.com/github/yaninabusquet-prog/data_science_prueba/blob/main/CEP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis de datos del CEP
# ### Sector Industrial Argentino

# %%
## Importación de librerías y dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/yaninabusquet-prog/data_science_prueba/refs/heads/main/Fichas%20CEP.csv"

df = pd.read_csv(url, sep=';')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2376 entries, 0 to 2375
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   anio                      2376 non-null   int64
#  1   id_sector_productivo      2376 non-null   object
#  2   nombre_sector_productivo  2376 non-null   object
#  3   nombre_variable           2376 non-null   object
#  4   valor                     2376 non-null   object
#  5   unidad_medida             2376 non-null   object
#  6   Viajes_Y_Turismo          0 non-null      float64
#  7   concepto_desc             0 non-null      float64
#  8   Socio                     0 non-null      float64
#  9   ADUANA                    0 non-null      float64
#  10  USO_ECONOMICO             0 non-null      float64
#  11  Producto                  0 non-null      float64
#  12  Provincia                 0 non-null      float64
# ...

# %%
df.columns
# Out:
# Index(['anio', 'id_sector_productivo', 'nombre_sector_productivo',
#        'nombre_variable', 'valor', 'unidad_medida', 'Viajes_Y_Turismo',
#        'concepto_desc', 'Socio', 'ADUANA', 'USO_ECONOMICO', 'Producto',
#        'Provincia', 'Macrobloque'],
#       dtype='object')

# %%
# Ver valores faltantes
df.isna().sum()
# Out:
# anio                           0
# id_sector_productivo           0
# nombre_sector_productivo       0
# nombre_variable                0
# valor                          0
# unidad_medida                  0
# Viajes_Y_Turismo            2376
# concepto_desc               2376
# Socio                       2376
# ADUANA                      2376
# USO_ECONOMICO               2376
# Producto                    2376
# Provincia                   2376
# Macrobloque                    0
# dtype: int64

# %%
# Estadísticas básicas
df.describe(include='all')
# Out:
#                anio id_sector_productivo nombre_sector_productivo  \
# count   2376.000000                 2376                     2376
# unique          NaN                   22                       22
# top             NaN                    D  INDUSTRIA_MANUFACTURERA
# freq            NaN                  108                      108
# mean    2015.907407                  NaN                      NaN
# std        3.117329                  NaN                      NaN
# min     2011.000000                  NaN                      NaN
# 25%     2013.000000                  NaN                      NaN
# 50%     2016.000000                  NaN                      NaN
# 75%     2019.000000                  NaN                      NaN
# max     2021.000000                  NaN                      NaN
#
#        nombre_variable valor unidad_medida  Viajes_Y_Turismo  concepto_desc  \
# count             2376  2376          2376               0.0            0.0
# ...
